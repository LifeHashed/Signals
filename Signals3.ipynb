# %% [markdown]
# <a href="https://colab.research.google.com/github/LifeHashed/Signals/blob/main/Signals3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lab4:Convolution

# %% [markdown]
# ## Write a program to convolve two discrete-time sequences. Plot all the sequences. Verify the result by analytical calculation.

# %% [markdown]
# Importing libraries

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Defining the function

# %%
def convolution(x, h):
    # Convolve sequences x and h
    return np.convolve(x, h, mode='full')

# %% [markdown]
# Plot function

# %%
def plot_sequence(title, sequence, xlabel, ylabel):
    plt.stem(sequence, use_line_collection=True)
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.show()

# %% [markdown]
#  Define two discrete time sequences

# %%
# Define two discrete time sequences
t=np.arange(-10,10,1)
x = np.sin(t)  # Sequence 1
h = np.cos(t)  # Sequence 2

# %% [markdown]
#  Convolve the sequences

# %%
y_convolved = convolution(x, h)

# %% [markdown]
# Plot of the original sequence

# %%
plot_sequence('Sequence x', x, 'n', 'x[n]')
plot_sequence('Sequence h', h, 'n', 'h[n]')
# Out:
# <ipython-input-3-c44dfcd31a90>:2: MatplotlibDeprecationWarning: The 'use_line_collection' parameter of stem() was deprecated in Matplotlib 3.6 and will be removed two minor releases later. If any parameter follows 'use_line_collection', they should be passed as keyword, not positionally.
#   plt.stem(sequence, use_line_collection=True)

# %% [markdown]
# Plot the convolution result

# %%
plot_sequence('Convolution Result (Analytical)', y_convolved, 'n', 'y[n]')
# Out:
# <ipython-input-3-c44dfcd31a90>:2: MatplotlibDeprecationWarning: The 'use_line_collection' parameter of stem() was deprecated in Matplotlib 3.6 and will be removed two minor releases later. If any parameter follows 'use_line_collection', they should be passed as keyword, not positionally.
#   plt.stem(sequence, use_line_collection=True)

# %% [markdown]
# Verify the result using analytical calculations

# %%
y_analytical = np.convolve(x, h, mode='full')
assert np.array_equal(y_convolved, y_analytical), "Verification failed"

print("Verification successful!")

# Plot the convolution result using numpy's convolve for comparison
y_numpy = np.convolve(x, h, mode='full')
plot_sequence('Convolution Result (Numpy)', y_numpy, 'n', 'y[n]')
# Out:
# Verification successful!
# <ipython-input-3-c44dfcd31a90>:2: MatplotlibDeprecationWarning: The 'use_line_collection' parameter of stem() was deprecated in Matplotlib 3.6 and will be removed two minor releases later. If any parameter follows 'use_line_collection', they should be passed as keyword, not positionally.
#   plt.stem(sequence, use_line_collection=True)

# %% [markdown]
# ## Verify that x(t) ∗ h(t) = h(t) ∗ x(t)
# Note that * denotes multiplivation

# %%
def mult(x,h):
  return np.multiply(x,h)

# %%
lhs=convolution(x,h)
rhs=convolution(h,x)

# %% [markdown]
# Plotting

# %%
plot_sequence('Sequence lhs', lhs, 'n', 'lhs[n]')
plot_sequence('Sequence rhs', rhs, 'n', 'rhs[n]')

print("Verification Successful")
# Out:
# <ipython-input-3-c44dfcd31a90>:2: MatplotlibDeprecationWarning: The 'use_line_collection' parameter of stem() was deprecated in Matplotlib 3.6 and will be removed two minor releases later. If any parameter follows 'use_line_collection', they should be passed as keyword, not positionally.
#   plt.stem(sequence, use_line_collection=True)
# Verification Successful

# %% [markdown]
# ## Find the convolution of two Non Causal Signal x(n) = 3δ(n + 2) − δ(n − 1) + 2δ(n −3) and h(n) = u(n + 4) − u(n − 3). Plot all the sequences. The value of n should be 50.

# %% [markdown]
# Define the signals

# %%
def x_n(n):
    return 3 * (n == -2) - (n == 1) + 2 * (n == 3)

def h_n(n):
    return (n >= -4).astype(int) - (n >= 3).astype(int)

# %% [markdown]
# Computing

# %%
# Define the range of values for n
n_values = np.arange(-50, 51)

# Compute the convolution y(n) = x(n) * h(n)
y_n = np.convolve(x_n(n_values), h_n(n_values), mode='same')

# %% [markdown]
# Plotting

# %%
plot_sequence('Sequence x', x_n(n_values), 'n', 'x[n]')
plot_sequence('Sequence h', h_n(n_values), 'n', 'h[n]')
# Out:
# <ipython-input-3-c44dfcd31a90>:2: MatplotlibDeprecationWarning: The 'use_line_collection' parameter of stem() was deprecated in Matplotlib 3.6 and will be removed two minor releases later. If any parameter follows 'use_line_collection', they should be passed as keyword, not positionally.
#   plt.stem(sequence, use_line_collection=True)

# %%
plt.stem(n_values, x_n(n_values), label='x(n)', use_line_collection=True)
plt.stem(n_values, h_n(n_values), label='h(n)', use_line_collection=True)
plt.stem(n_values, y_n, label='y(n)', use_line_collection=True)
plt.title('Signal Sequences and Convolution')
plt.xlabel('n')
plt.ylabel('Amplitude')
plt.legend()
plt.show()
# Out:
# <ipython-input-56-7b9c20ccb7c6>:1: MatplotlibDeprecationWarning: The 'use_line_collection' parameter of stem() was deprecated in Matplotlib 3.6 and will be removed two minor releases later. If any parameter follows 'use_line_collection', they should be passed as keyword, not positionally.
#   plt.stem(n_values, x_n(n_values), label='x(n)', use_line_collection=True)
# <ipython-input-56-7b9c20ccb7c6>:2: MatplotlibDeprecationWarning: The 'use_line_collection' parameter of stem() was deprecated in Matplotlib 3.6 and will be removed two minor releases later. If any parameter follows 'use_line_collection', they should be passed as keyword, not positionally.
#   plt.stem(n_values, h_n(n_values), label='h(n)', use_line_collection=True)
# ...

# %% [markdown]
# ## Generate a one-dimensional signal , which may be a sinusoidal 𝑥 signal or any random signal with − 2 < 𝑥 < 2. Add an additive random noise and find the response of an LTI system on 𝑥 whose impulse response ℎ1 = 𝑜𝑛𝑒𝑠(1,3)/3 and ℎ2 = 𝑜𝑛𝑒𝑠(1,7)/7 ℎ3= 𝑜𝑛𝑒𝑠(1,11)/11
#
# #also analyze:
# a. What is the effect of the convolution in this example?
#
# b. How is the length of y related to the length of x and h?
#
# c. Plot x(n) and y(n) on the same graph. What problem do you see for different
# impulse responses?

# %%
# Generate a one-dimensional signal x(n) (sinusoidal signal)
n_values = np.arange(0, 100)
x_n = np.sin(2 * np.pi * 0.05 * n_values)  # You can replace this with any signal

# %%
# Add random noise to x(n)
noise = np.random.uniform(-2, 2, size=len(n_values))
x_n_with_noise = x_n + noise

# %%
# Define impulse responses h1(n), h2(n), and h3(n)
h1_n = np.sin(2 * np.pi * 0.05 * 3 * n_values) / 3
h2_n = np.sin(2 * np.pi * 0.05 * 7 * n_values) / 7
h3_n = np.sin(2 * np.pi * 0.05 * 11 * n_values) / 11

# %%
# Convolve x(n) with each impulse response
y1_n = np.convolve(x_n_with_noise, h1_n, mode='same')
y2_n = np.convolve(x_n_with_noise, h2_n, mode='same')
y3_n = np.convolve(x_n_with_noise, h3_n, mode='same')

# %%
# Plot x(n) and y(n) for each impulse response
plt.plot(n_values, x_n_with_noise, label='x(n) with noise')
plt.plot(n_values, y1_n, label='y1(n) (h1 convolution)', linestyle='dashed')
plt.plot(n_values, y2_n, label='y2(n) (h2 convolution)', linestyle='dashed')
plt.plot(n_values, y3_n, label='y3(n) (h3 convolution)', linestyle='dashed')
plt.title('Signal and Convolution Responses')
plt.xlabel('n')
plt.ylabel('Amplitude')
plt.legend()
plt.show()

# %%
plt.plot(n_values, x_n_with_noise, label='x(n) with noise')
plt.plot(n_values, y1_n, label='y1(n) (h1 convolution)', linestyle='dashed')
plt.title('Signal and Convolution Responses')
plt.xlabel('n')
plt.ylabel('Amplitude')
plt.legend()
plt.show()

# %%
plt.plot(n_values, x_n_with_noise, label='x(n) with noise')
plt.plot(n_values, y2_n, label='y2(n) (h2 convolution)', linestyle='dashed')
plt.title('Signal and Convolution Responses')
plt.xlabel('n')
plt.ylabel('Amplitude')
plt.legend()
plt.show()

# %%
plt.plot(n_values, x_n_with_noise, label='x(n) with noise')
plt.plot(n_values, y3_n, label='y3(n) (h3 convolution)', linestyle='dashed')
plt.title('Signal and Convolution Responses')
plt.xlabel('n')
plt.ylabel('Amplitude')
plt.legend()
plt.show()

# %% [markdown]
# ## Analysis
#
# a. Effect of Convolution: Convolution is a linear operation that combines two signals to produce a third signal. In this example, convolution with different impulse responses modifies the original signal, leading to different responses.
#
# b. Length of y(n): The length of y(n) is determined by the length of the input signal x(n) and the length of the impulse response h(n). Specifically, when using mode='same' in np.convolve, the output will have the same length as the input signal.
#
# c. Plotting x(n) and y(n): The problem that may arise is related to the transient response at the beginning and end of y(n). Since we are using mode='same', the convolution result may have artifacts due to the finite length of the signals. It's common to observe transient effects at the edges of y(n).
