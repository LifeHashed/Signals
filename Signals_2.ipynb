# %% [markdown]
# <a href="https://colab.research.google.com/github/LifeHashed/Signals/blob/main/Signals_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Lab3

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Defining the function

# %%
def x(t):
    if 0 <= t < 5:
        return 1
    elif 5 <= t < 8:
        return 2
    elif 8 <= t < 12:
        return 5
    else:
        return 0

# %% [markdown]
# Generating x(t) plot

# %%
# Generate time values
t_values = np.linspace(-2, 15, 1000)  # Adjust the range as needed

# Evaluate x(t) for each time value
x_values = [x(t) for t in t_values]

# Plot the signal
plt.plot(t_values, x_values, label='x(t)')
plt.title('Signal x(t)')
plt.xlabel('Time (t)')
plt.ylabel('Amplitude')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# Defining the other function

# %%
def y(t):
    if 0 <= t < 7:
        return 2
    elif 7 <= t < 10:
        return 0
    elif 10 <= t < 15:
        return 7
    else:
        return 0

# %% [markdown]
# Generating y(t) plot

# %%
# Generate time values
t_values = np.linspace(-2, 17, 1000)  # Adjust the range as needed

# Evaluate y(t) for each time value
y_values = [y(t) for t in t_values]

# Plot the signal
plt.plot(t_values, y_values, label='y(t)')
plt.title('Signal y(t)')
plt.xlabel('Time (t)')
plt.ylabel('Amplitude')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# ##Performing Operations

# %% [markdown]
# 1.x(t)+y(t)

# %%
# Generate time values
t_values = np.linspace(-2, 17, 1000)  # Adjust the range as needed

# Evaluate x(t) and y(t) for each time value
x_values = [x(t) for t in t_values]
y_values = [y(t) for t in t_values]

# Add x(t) and y(t) to get the sum signal
sum_values = np.add(x_values, y_values)

# Plot the signals
plt.plot(t_values, x_values, label='x(t)')
plt.plot(t_values, y_values, label='y(t)')
plt.plot(t_values, sum_values, label='x(t) + y(t)', linestyle='--', linewidth=2)
plt.title('Sum of x(t) and y(t)')
plt.xlabel('Time (t)')
plt.ylabel('Amplitude')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# 2.x(t)-y(t)
#
# 3.x(t)*y(t)

# %%
# Generate time values
t_values = np.linspace(-2, 17, 1000)  # Adjust the range as needed

# Evaluate x(t) and y(t) for each time value
x_values = [x(t) for t in t_values]
y_values = [y(t) for t in t_values]

# Subtract y(t) from x(t) to get the difference signal
diff_values = np.subtract(x_values, y_values)

# Multiply x(t) and y(t) to get the product signal
prod_values = np.multiply(x_values, y_values)

# Plot the signals
plt.plot(t_values, x_values, label='x(t)')
plt.plot(t_values, y_values, label='y(t)')
plt.plot(t_values, diff_values, label='x(t) - y(t)', linestyle='--', linewidth=2)
plt.plot(t_values, prod_values, label='x(t) * y(t)', linestyle='-.', linewidth=2)
plt.title('Subtraction and Multiplication of x(t) and y(t)')
plt.xlabel('Time (t)')
plt.ylabel('Amplitude')
plt.grid(True)
plt.legend()
plt.show()
